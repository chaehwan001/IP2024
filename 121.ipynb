# %%
import numpy as np
import cv2

# Load an color image in grayscale

# %%
img = cv2.imread('cat2.jpg') #뒤에 0을 붙이면 흑백이됨 ('cat2.jpg',0)

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL) #해도 되고 안해도 됨
cv2.imshow('image',img) #창의 이름을 'image로 설정'
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite('messigray.png',img) #'' 이름으로 저장
# Out:
# True

# %%
img = cv2.imread('cat2.jpg',0)
cv2.imshow('image',img)
k = cv2.waitKey(0)
if k == 27: # esc를 누르면 창을 닫음
    cv2.destroyAllWindows()
elif k == ord('s'): #  s를 누르면 저장하고 파일 생성
    cv2.imwrite('cat00.png',img)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

# %%
img = cv2.imread('winter.jpg',0)
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
plt.show()
